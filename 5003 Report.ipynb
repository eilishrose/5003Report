# %%
print("Hello World")
# Out:
# Hello World

# %%
import pysheds
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c7d5f8a749be> in <module>
# ----> 1 import pysheds
#
# ModuleNotFoundError: No module named 'pysheds'

# %%
import pysheds
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-c7d5f8a749be> in <module>
# ----> 1 import pysheds
#
# ModuleNotFoundError: No module named 'pysheds'

# %%
import matplotlib
import matplotlib.pyplot
import csv
import matplotlib.animation
#import richdem

snowslope =[]

# Import raster data set and append data to list
f = open('snowslope.csv', newline='' )
reader = csv.reader(f,  delimiter=',', quoting=csv.QUOTE_NONNUMERIC)
for row in reader: 
    rowlist = []
    snowslope.append(rowlist)
    for value in row:
        rowlist.append(value)
        #print(value)
f.close()

matplotlib.pyplot.xlim(0, 99)
matplotlib.pyplot.ylim(0, 99)
matplotlib.pyplot.imshow(snowslope)
